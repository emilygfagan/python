# %% [markdown]
# ## Importing .csv file to preview using Pandas DataFrame.

# %%
import pandas as pd

# %%
ss_df = pd.read_excel("SS_Sales.xlsx") #creating dataframe and uploading excel file

# %%
ss_df.head() #showing first 5 rows of dataset
# Out:
#           Category  Category (copy)        City        Country Customer ID  \
# 0        Furniture        Furniture   Henderson  United States    CG-12520
# 1        Furniture        Furniture   Henderson  United States    CG-12520
# 2  Office Supplies  Office Supplies     Seattle  United States    IM-15070
# 3       Technology       Technology  Richardson  United States    GH-14485
# 4        Furniture        Furniture  Richardson  United States    GH-14485
#
#   Customer Name Order Date        Order ID  Postal Code       Product ID  ...  \
# 0   Claire Gute 2017-08-11  CA-2017-152156        42420  FUR-BO-10001798  ...
# 1   Claire Gute 2017-08-11  CA-2017-152156        42420  FUR-CH-10000454  ...
# 2  Irene Maddox 2017-05-12  CA-2017-161389        98103  OFF-BI-10003656  ...
# 3     Gene Hale 2017-08-12  CA-2017-117590        75080  TEC-PH-10004977  ...
# 4     Gene Hale 2017-08-12  CA-2017-117590        75080  FUR-FU-10003664  ...
#
# ...

# %%
list(ss_df.columns) #listing column names
# Out:
# ['Category',
#  'Category (copy)',
#  'City',
#  'Country',
#  'Customer ID',
#  'Customer Name',
#  'Order Date',
#  'Order ID',
#  'Postal Code',
#  'Product ID',
#  'Product Name',
#  'Region',
#  'Row ID',
#  'Segment',
#  'Segment (Blues)',
#  'Ship Date',
#  'Ship Mode',
#  'State',
#  'Sub-Category',
#  'Year',
#  'Bottom Half',
#  'Discount',
#  'Number of Records',
#  'Outer Venn Position',
#  'Overlapping Customers',
#  'Overlapping Position',
#  'Profit',
#  'Profit Ratio',
#  'Quantity',
#  'Sales']
