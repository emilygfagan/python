# %% [markdown]
# # Importing CSV file to view as preview using Pandas.

# %%
import pandas as pd

# %%
os_df = pd.read_csv("Office_Supply_Company.csv")

# %%
os_df.head()
# Out:
#           Category             City        Country Customer ID  \
# 0        Furniture        Henderson  United States    CG-12520
# 1        Furniture        Henderson  United States    CG-12520
# 2  Office Supplies      Los Angeles  United States    DV-13045
# 3        Furniture  Fort Lauderdale  United States    SO-20335
# 4  Office Supplies  Fort Lauderdale  United States    SO-20335
#
#      Customer Name  Order Date        Order ID  Postal Code       Product ID  \
# 0      Claire Gute   8/11/2017  CA-2017-152156      42420.0  FUR-BO-10001798
# 1      Claire Gute   8/11/2017  CA-2017-152156      42420.0  FUR-CH-10000454
# 2  Darrin Van Huff   12/6/2017  CA-2017-138688      90036.0  OFF-LA-10000240
# 3   Sean O'Donnell  11/10/2016  US-2016-108966      33311.0  FUR-TA-10000577
# 4   Sean O'Donnell  11/10/2016  US-2016-108966      33311.0  OFF-ST-10000760
#
#                                         Product Name  ... Bottom Half  \
# ...
