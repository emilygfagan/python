# %% [markdown]
# ### University Data Practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uni = pd.read_csv("Practice_2_Raw_Data (1).csv")

# %% [markdown]
# Data Insights:
# - Number rows / columns
# - Values
# - Data Types
# - Missing Values

# %%
# shape displays number of rows and columns in dataset
uni.shape
# Out:
# (45, 11)

# %%
# head displays top 5 observations of dataset
uni.head()
# Out:
#      Student Name  University Package Offered  Type of Company  \
# 0     Rudra Verma    Harvard        $230,000           Finance
# 1  Aayansh Sharma      Boston        $40,000   Pharmaceutical
# 2   Aditya Pandey  Washington        $80,000                IT
# 3     Dhruv Verma      Boston        $45,000           Finance
# 4      Veer Patil      Boston        $90,000           Finance
#
#   Student Native Country  Prior work Experience in years           Domain  \
# 0                  India                               5          Finance
# 1                  India                               5  Pharmaceutical
# 2                  India                               3               IT
# 3                  India                               5          Finance
# 4                  India                               5          Finance
#
#   Passport Number Date of Birth Date of Admission Date of Placement
# 0        F2356145     2/25/1990          4/3/2016        12/25/2018
# 1        J4563219     2/17/1989          4/8/2017        10/11/2019
# 2        W4526893     7/21/1991         3/17/2017         1/19/2019
# 3        K4578236      3/8/1990         3/14/2016         3/16/2021
# 4        K4578237      9/1/1989         3/15/2017         6/28/2019

# %%
# info displays datatype and information
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Student Name                    45 non-null     object
#  1   University                      45 non-null     object
#  2   Package Offered                 45 non-null     object
#  3   Type of Company                 45 non-null     object
#  4   Student Native Country          45 non-null     object
#  5   Prior work Experience in years  45 non-null     int64
#  6   Domain                          45 non-null     object
#  7   Passport Number                 45 non-null     object
#  8   Date of Birth                   45 non-null     object
#  9   Date of Admission               45 non-null     object
#  10  Date of Placement               45 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 4.0+ KB

# %%
"""
Displaying missing values with isnull and sum
to display number of null values
""" 
uni.isnull().sum()
# Out:
# Student Name                      0
# University                        0
# Package Offered                   0
# Type of Company                   0
# Student Native Country            0
# Prior work Experience in years    0
# Domain                            0
# Passport Number                   0
# Date of Birth                     0
# Date of Admission                 0
# Date of Placement                 0
# dtype: int64

# %%
# percentage of null values in each column
(uni.isnull().sum()/(len(uni)))*100
# Out:
# Student Name                      0.0
# University                        0.0
# Package Offered                   0.0
# Type of Company                   0.0
# Student Native Country            0.0
# Prior work Experience in years    0.0
# Domain                            0.0
# Passport Number                   0.0
# Date of Birth                     0.0
# Date of Admission                 0.0
# Date of Placement                 0.0
# dtype: float64

# %%
uni.head(20)
# Out:
#         Student Name  University Package Offered  Type of Company  \
# 0        Rudra Verma    Harvard        $230,000           Finance
# 1     Aayansh Sharma      Boston        $40,000   Pharmaceutical
# 2      Aditya Pandey  Washington        $80,000                IT
# 3        Dhruv Verma      Boston        $45,000           Finance
# 4         Veer Patil      Boston        $90,000           Finance
