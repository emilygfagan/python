# %% [markdown]
# ### Employee Data Practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emp = pd.read_csv("employee_data_preview.csv")

# %%
# shape: rows and columns in dataset
emp.shape
# Out:
# (14806, 14)

# %%
# head: top n observations of dataset. default is 5
emp.head()
# Out:
#    S.no       Employee Name      City Blood_Group Gender Birth_Date  Salary  \
# 0     1     Kathleen Newman   San Joe          A+      F  2/17/1988     low
# 1     2       Scott Shelton    Austin          A+      M  8/17/1941     low
# 2     3      David Santiago   San Joe          A-      F   6/6/1962  medium
# 3     4       Caroline Bell  Columbus          O-      F   4/7/1998  medium
# 4     5  Elizabeth Clements    Austin         AB-      F  1/26/1986     low
#
#            Department  Satisfaction_level(0-1)  Number_Project_Currently_Wrkg  \
# 0  Product Management                      1.0                              2
# 1               Sales                      1.0                              1
# 2             Support                      1.0                              1
# 3                  HR                      1.0                              3
# 4             Support                      1.0                              1
#
# ...

# %%
# info: datatype and information
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14806 entries, 0 to 14805
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   S.no                           14806 non-null  int64
#  1   Employee Name                  14806 non-null  object
#  2   City                           14806 non-null  object
#  3   Blood_Group                    14806 non-null  object
#  4   Gender                         14806 non-null  object
#  5   Birth_Date                     14806 non-null  object
#  6   Salary                         14806 non-null  object
#  7   Department                     14806 non-null  object
#  8   Satisfaction_level(0-1)        14806 non-null  float64
#  9   Number_Project_Currently_Wrkg  14806 non-null  int64
#  10  Average_Monthly_Hours          14806 non-null  int64
#  11  Time_Spent_Company (years)     14806 non-null  int64
# ...

# %%
# isnull and sum: number of null values
emp.isnull().sum()
# Out:
# S.no                             0
# Employee Name                    0
# City                             0
# Blood_Group                      0
# Gender                           0
# Birth_Date                       0
# Salary                           0
# Department                       0
# Satisfaction_level(0-1)          0
# Number_Project_Currently_Wrkg    0
# Average_Monthly_Hours            0
# Time_Spent_Company (years)       0
# Work_Accident                    0
# Promotion_Last_5Years            0
# dtype: int64

# %%
"""
Dataset is very clean and quite small. 
Using .head() again to display more rows to preview.
No more EDA needed for tasks.
"""
emp.head(20)
# Out:
#     S.no       Employee Name         City Blood_Group Gender  Birth_Date  \
# 0      1     Kathleen Newman      San Joe          A+      F   2/17/1988
# 1      2       Scott Shelton       Austin          A+      M   8/17/1941
# 2      3      David Santiago      San Joe          A-      F    6/6/1962
# 3      4       Caroline Bell     Columbus          O-      F    4/7/1998
# 4      5  Elizabeth Clements       Austin         AB-      F   1/26/1986
# 5      6     Christian Moore      Houston          A+      M  12/14/1916
# 6      7      Antonio Miller   Fort Worth         AB-      M   7/20/1983
# 7      8         Brent Allen  San Antonio          A+      M  11/23/1959
# 8      9        Jason Dawson  San Antonio          B+      M  11/30/1998
# 9     10      Whitney Greene  los Angeles          A+      F    7/6/1941
# 10    11         Donald Long   Fort Worth          A+      M   2/17/1943
# 11    12     Katherine Evans      Houston         AB+      F   8/17/1970
# ...
